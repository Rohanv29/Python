# %% [markdown]
# ## **Module 1: Introduction to Python, Python Interpreter, Interactive Mode & Python Basics**

# %% [markdown]
# ## **Python 3 Installation On Windows**
# Follow the steps described in the below document to Install and configure Python 3 on Windows environment, and Add Python path to environment variables
# **Python_3-Installation-On-Windows.pdf**

# %% [markdown]
# ## **Choose and install an editor**
#  For Linux, prefer SublimeText. <br>
#  Windows users will likely use IDLE by default. <br>
#  Options include Jupyter Notebook, VS Code, Google Colab, Cursor, Spyder, Notepad++, PyCharm, Eclipse, etc.

# %% [markdown]
# ## **Python PIP**
# Python PIP is the package manager used to install, update and manage Python packages and libraries. It allows users to easily download packages from the Python Package Index (PyPI) directly through the command line. PIP is commonly used to add external libraries that are not included with Python by default.
#
# The basic syntax of a PIP command is:
#
# pip <command>

# %% [markdown]
# ## **Check PIP Version**
# Use the following command in the terminal or command prompt to check whether PIP is installed:

# %%
pip --version
# Out:
# pip 26.1.1 from C:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip (python 3.13)
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## **Installing Packages**
# PIP provides the install command to download and install Python packages from PyPI. For example, the following command installs the NumPy package. Below is the syntax:
#
# pip install package_name
#
# For Example:
#
# **pip install jupyter**

# %% [markdown]
# ## **Viewing Package Information**
# The pip show command is used to display details about an installed package such as version, location and dependencies. Below is the syntax:
#
# pip show package_name
#
# Example:
#
# **pip show Jupyter**

# %% [markdown]
# ## **Listing Installed Packages**
# The pip list command is used to display all packages installed in the current Python environment. Below is the syntax:
#
# **pip list**

# %% [markdown]
# ## **Uninstalling Packages**
# The pip uninstall command is used to remove an installed package from the system. Below is the syntax:
#
# pip uninstall package_name
#
# Example:
#
# **pip uninstall numpy**

# %% [markdown]
# ## **IDLE Development Environment**
# IDLE is an Integrated Development Environment for Python, typically used on Windows <br>
# Multi-window text editor with syntax highlighting, auto-completion, smart indent and other. <br>
# Python shell with syntax highlighting. <br>
# Integrated debugger
# with stepping, persistent breakpoints,
# and call stack visibility v

# %% [markdown]
# ## **What is Python?**
#
# Python is a
#
# High-Level Programming Language <br>
# Interpreted Language <br>
# Object-Oriented <br>
# Open Source <br>
# Cross Platform <br>
# Easy to Learn
#
# Created by:
#
# Guido van Rossum (1991)

# %% [markdown]
# ## **Python Basics**
# Python is an interpreted language, which means the source code of a Python program is converted
# into bytecode that is then executed by the Python virtual machine. Python is different from major compiled
# languages, such as C and C + +, as Python code is not required to be built and linked like code for these languages.

# %% [markdown]
# ## **Why Python?**
#
# Python is used in
#
# Artificial Intelligence <br>
# Machine Learning <br>
# Data Science <br>
# Web Development <br>
# Cyber Security <br>
# Automation <br>
# IoT <br>
# Cloud Computing

# %% [markdown]
# ## **Features of Python**

# %% [markdown]
# # **1. Easy to Learn**

# %% [markdown]
# Python is a relatively easy-to-learn language. Its syntax is simple for a beginner to learn and
# understand. When compared with languages like C or Java, there is minimal boilerplate code required in executing
# a Python program.

# %% [markdown]
# Python is a simple programming language. When we read Python program,we can feel like reading english statements. The syntaxes are very simple and only 30+ keywords are available. When compared with other languages, we can write programs with very less number of lines. Hence more readability and simplicity. We can reduce development and cost of the project.

# %%
# To print Hello World in Python
print("Hello")
# Out:
# Hello

# %%
'''
instead of C
#include<stdio.h>

int main()
{
printf("Hello");
return 0;
}
'''
'''
instead of Java
public class HellowWorld
{
  public static void main(String[] args)
  {
    System.out.println("Hello World"); 
  }
}
'''
# Out:
# '\ninstead of Java\npublic class HellowWorld\n{\n  public static void main(String[] args)\n  {\n    System.out.println("Hello World"); \n  }\n}\n'

# %%
# To print the sum of two numbers in Python
a = 10
b = 20
print("The Sum:",(a+b))
# Out:
# The Sum: 30

# %%
'''
instead of C
#include<stdio.h>

int main()
{
int a,b;
a=10;
b=20;
printf("The Sum:%d", (a+b));
return 0;
}
'''
'''
instead of Java
public class HellowWorld
{
  public static void main(String[] args)
  {
    int a,b;
    a=10;
    b=20;
    System.out.println("The Sum:"+(a+b)); 
  }
}
'''
# Out:
# '\ninstead of Java\npublic class HellowWorld\n{\n  public static void main(String[] args)\n  {\n    int a,b;\n    a=10;\n    b=20;\n    System.out.println("The Sum:"+(a+b)); \n  }\n}\n'

# %% [markdown]
# # **2. Interpreted Language**
#
# Python executes line by line.

# %%
print("Line 1")

print("Line 2")

print("Line 3")
# Out:
# Line 1
# Line 2
# Line 3

# %% [markdown]
# # **3. Platform Independent**
#
# Once we write a Python program,it can run on any platform without rewriting once again. Internally PVM is responsible to convert into machine understandable form.
#
# Same code works on
#
# Windows <br>
# Linux <br>
# macOS

# %% [markdown]
# # **4. Freeware and Open Source**
#
# We can use Python software without any licence and it is freeware. Its source code is open,so that we can we can customize based on our requirement. Eg: Jython is customized version of Python to work with Java Applications.
#
# Free to download
# https://python.org

# %% [markdown]
# ## **5. Object Oriented**
#
# Supports
#
# Classes <br>
# Objects <br>
# Inheritance <br>
# Encapsulation <br>
# Polymorphism <br>
# Abstraction

# %% [markdown]
# ## **6. General purpose language**
# Simple yet very powerful language
#
# Console Application & Scripts <br>
# Desktop Application <br>
# Web Application <br>
# Game Development <br>
# Machine Learning <br>
# Deep Learning <br>
# Artificial intelligence (AI) <br>
# Big Data <br>
# Internet of Things

# %% [markdown]
# ## **7. Huge Library Support**
#
# Examples
#
# NumPy <br>
# Pandas <br>
# Matplotlib <br>
# TensorFlow <br>
# OpenCV

# %% [markdown]
# ## **8. Multiparadigm Support**
#
# Procedural Style Programming like C <br>
# Oops like Java <br>
# Functional Programming like list

# %% [markdown]
# ## **9. Dynamically Typed**
#
# In Python we are not required to declare type for variables. Whenever we are assigning the value, based on value, type will be allocated automatically. Hence Python is considered as dynamically typed language. But Java, C etc are Statically Typed Languages b'z we have to provide type at the beginning only. This dynamic typing nature will provide more flexibility to the programmer.

# %%
x = 10

name = "Rahul"

marks = 95.5

# %%
print(x)
print(name)
print(marks)
# Out:
# 10
# Rahul
# 95.5

# %% [markdown]
# ## **10. Extensible**
# Extensibility of Python is one of its most important characteristics. Python has a huge number of
# modules easily available that can be readily installed and used. These modules cover every aspect of programming
# from data access to implementation of popular algorithms. This easy-to-extend feature ensures that a Python
# developer is more productive, as a large array of problems can be solved by available libraries.

# %% [markdown]
# ## **11. High Level Programming language**
# Python is high level programming language and hence it is programmer friendly language. Being a programmer we are not required to concentrate low level activities like memory management and security etc.

# %% [markdown]
# ## **12. Portability**
# Python programs are portable. i.e. we can migrate from one platform to another platform very easily. Python programs will provide same results on any platform.

# %% [markdown]
# ## **13. Embedded**
# We can use Python programs in any other language programs. i.e we can embed Python programs anywhere.

# %% [markdown]
# ## **Practical Exercise**
#
# Predict Output

# %%
x = 10

print(type(x))

x = "Python"

print(type(x))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# ## **Python is Compiled and Interpreted**
# Python language is interpreted, but the python programs are first compiled and then interpreted. The compilation
# part is hidden from the programmer thus, many programmers believe that it is an interpreted language. The
# compilation part is done first when we execute our code, and this will generate byte code and internally this byte
# code gets converted by the Python Virtual Machine (PVM) according to the underlying platform (machine +
# operating system).  The compiled part get deleted by the python(as soon as you execute your code) just it does
# not want programmers to get into complexity.
#
# **print("i am learning python")**
# **print("i am enjoying it")**
#
# now if you run this code using command prompt just save this above code in notepad and save with the extension
# “.py”

# %% [markdown]
# **D:\python_prog>python -m py_compile first.py**
#
# as you press enter the byte code will get generated. A folder created and this will contain the byte code of your
# program. This folder is in the python_prog folder where you will save your python codes.
# now to run the compiled byte code just type the following command in the command prompt:

# %% [markdown]
# **D:\python_prog\__pycache__>python first.cpython-313.pyc**
#
# the extension .pyc is python compiler. Thus, it is proven that python programs are both compiled as well as
# interpreted!! but the compilation part is hidden from the programmer.

# %% [markdown]
# ## **Python Interpreter: Interactive Mode**
# Python's interactive mode executes code line-by-line, instantly returning results via a REPL (Read-Eval-Print Loop). In contrast, normal (or script) mode executes entire pre-written .py files from start to finish. Interactive mode is ideal for quick testing and debugging, while normal mode builds persistent programs

# %%
#2+3
x=10
y=5
x+y
# Out:
# 15

# %% [markdown]
# ## **Python Interpreter: Normal Mode**
# Write your Python code in a text editor or IDE and save it as a file (e.g., main.py). To run this file, open your terminal and pass the file name directly to the interpreter.
#
# **python main.py**

# %% [markdown]
# ## **Python Identifiers**
# Identifiers are the names given to variables, classes, methods, etc. For example,
#
# **language = 'Python'**
#
# Here, language is a variable (an identifier) which holds the value 'Python'.
# We cannot use keywords as variable names as they are reserved names that are built-in in Python. For example,
#
# **continue = 'Python'**
#
# The above code is wrong because we have used continue as a variable name.

# %% [markdown]
# ## **Rules for Naming an Identifier**
# • Identifiers cannot be a keyword. <br>
# • Identifiers are case-sensitive. <br>
# • It can have a sequence of letters and digits. However, it must begin with a letter or _. The first letter of
# an identifier cannot be a digit. <br>
# • It's a convention to start an identifier with a letter rather _. <br>
# • Whitespaces are not allowed. <br>
# • We cannot use special symbols like !, @, #, $, and so on.

# %%
#Valid Identifiers
highest_score = 10
print(highest_score)
# Out:
# 10

# %%
#Invalid Identifiers 
highest score =20
#1name = 30
print(highest score)
#print(1name)
# Out:
#   Cell In[10], line 2
#     highest score =20
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## **Things to Remember**
# Python is a case-sensitive language. This means, Variable and variable are not the same.
# Always give the identifiers a name that makes sense. While c = 10 is a valid name, writing count = 10 would
# make more sense, and it would be easier to figure out what it represents when you look at your code after a long
# gap.
# Multiple words can be separated using an underscore, like this_is_a_long_variable.

# %%
Count = 10
print(count)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 Count = 10
# ----> 2 print(count)
#
# NameError: name 'count' is not defined

# %% [markdown]
# ## **Python Comments**
# In computer programming, comments are hints that we use to make our code more understandable.
# Comments are completely ignored by the interpreter.
# In Python, there are two types of comments:
# • single-line comment
# • multi-line comment

# %%
## single-line comment

# declare and initialize two variables 
num1 = 6 
num2 = 9 
 
# print the output 
print('This is output')
# Out:
# This is output

# %%
## multi-line comment

''' This is also a 
perfect example of 
multi-line comments '''

# %% [markdown]
# ## **Reserved Words (Keywords)**
#
# Keywords are predefined words.
#
# Cannot be used as variable names.

# %%
##Display All Keywords
import keyword

print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
#Count Keywords
import keyword

print(len(keyword.kwlist))
# Out:
# 35

# %%
#Practical Activity

#Check whether a word is keyword.

import keyword

print(keyword.iskeyword("for"))

print(keyword.iskeyword("hello"))

print(keyword.iskeyword("while"))
# Out:
# True
# False
# True

# %% [markdown]
# ## **Indentation**
#
# Python uses indentation instead of
#
# {}

# %%
#Correct

age = 20

if age >=18:
    print("Eligible")

# %%
#Wrong

age=20

if age>=18:
print("Eligible")

# %%
#Example
marks = 75

if marks>=40:
    print("Pass")
    print("Congratulations")

print("Program Finished")

# %%
#Practice
number=15

if number%2==0:
    print("Even")
else:
    print("Odd")

# %%
#Student Information

name = "Amit"
roll = 101
branch = "CSE"

print(name)
print(roll)
print(branch)
# Out:
# Amit
# 101
# CSE

# %%
#Area of Circle

radius = 7
area = 3.14 * radius * radius
print(area)
# Out:
# 153.86

# %%
#Check Eligible for Voting

age = 18

if age>=18:
    print("Eligible")
else:
    print("Not Eligible")
# Out:
# Eligible

# %%
#Keyword Checker

import keyword

word = input("Enter a word : ")
print(keyword.iskeyword(word))
# Out:
# Enter a word :  india
# False

# %%
#Calculator

a = 15
b = 5

print("Addition =",a+b)
print("Subtraction =",a-b)
print("Multiplication =",a*b)
print("Division =",a/b)
# Out:
# Addition = 20
# Subtraction = 10
# Multiplication = 75
# Division = 3.0

# %% [markdown]
# ## **Problem Statement**
#
# A college wants to create a simple Python-based application that stores and displays basic student details while ensuring correct use of Python identifiers, comments, and indentation.
#
# **Requirements**
# Store student's name, roll number, branch, and marks.
# Check whether the student has passed (marks ≥ 40).
# Display all information clearly.
# Include comments explaining the code.
# Use valid identifiers and proper indentation.

# %%
## Solution

student_name = "Ayesha"
roll_number = 202501
branch = "Computer Science"
marks = 78

print("===== Student Result =====")
print("Name       :", student_name)
print("Roll No.   :", roll_number)
print("Branch     :", branch)
print("Marks      :", marks)

if marks >= 40:
    print("Result     : PASS")
else:
    print("Result     : FAIL")
# Out:
# ===== Student Result =====
# Name       : Ayesha
# Roll No.   : 202501
# Branch     : Computer Science
# Marks      : 78
# Result     : PASS

# %% [markdown]
# ## **Python Variables**
# In programming, a variable is a container (storage area) to hold data. For example,
#
# number = 10
#
# # assign value to site_name variable
# college_name = 'psit'
#
# Python is a type-inferred language, so you don't have to explicitly define the variable type. It
# automatically knows that psit is a string and declares the college_name variable as a string.

# %%
#Changing the Value of a Variable in Python 
college_name = 'psit' 
print(college_name) 
 
# assigning a new value to site_name 
college_name = 'KIT' 
 
print(college_name)

# %%
#Assigning multiple values to multiple variables 
a, b, c = 5, 3.2, 'Hello' 
 
print(a)  # prints 5 
print(b)  # prints 3.2 
print(c)  # prints Hello

# %%
#If we want to assign the same value to multiple variables at once, we can do this as: 
site1 = site2  = 'flipcart.com' 
 
print(site1)  # prints flipcart.com 
print(site2)  # prints flipcart.com

# %% [markdown]
# ## **Python Constants**
# A constant is a special type of variable whose value cannot be changed.
# In Python, constants are usually declared and assigned in a module

# %%
#Create a constant.py: 
# declare constants  
PI = 3.14 
GRAVITY = 9.8

# %%
#Create a main.py: 
# import constant file we created above 
import constant 
 
print(constant.PI) # prints 3.14 
print(constant.GRAVITY) # prints 9.8

# %% [markdown]
# In the above example, we created the constant.py module file. Then, we assigned the constant value
# to PI and GRAVITY.
# After that, we create the main.py file and import the constant module. Finally, we printed the constant value.

# %% [markdown]
# ## **Python Literals**
# Literals are representations of fixed values in a program. They can be numbers, characters, or strings, etc. For
# example, 'Hello, World!', 12, 23.0, 'C', etc.
# Literals are often used to assign values to variables or constants. For example,
# site_name = 'flipcart.com'

# %% [markdown]
# ## *Python Numeric Literals*
# Numeric Literals are immutable (unchangeable). Numeric literals can belong to 3 different numerical
# types: Integer, Float, and Complex.

# %% [markdown]
# ## *Python Boolean Literals*
# There are two boolean literals: True and False.

# %% [markdown]
# ## *String and Character Literals in Python*
# Character literals are unicode characters enclosed in a quote. For example,
# some_character = 'S'
# Here, S is a character literal assigned to some_character.
# Similarly, String literals are sequences of Characters enclosed in quotation marks.
# For example,
# some_string = 'Python is fun'
# Here, 'Python is fun' is a string literal assigned to some_string.
